# %% [markdown]
# # Simple Chat
#
# A simple demonstration of two agents talking to each other.

# %%
import json
import sys
sys.path.insert(0, '..')

import tinytroupe
from tinytroupe.agent import TinyPerson
from tinytroupe.environment import TinyWorld, TinySocialNetwork
from tinytroupe.examples import *
# Out:
# !!!!
# DISCLAIMER: TinyTroupe relies on Artificial Intelligence (AI) models to generate content.
# The AI models are not perfect and may produce inappropriate or inacurate results.
# For any serious or consequential use, please review the generated content before using it.
# !!!!
#
# Looking for default config on: C:\Users\pdasilva\repos\TinyTroupe\examples\..\tinytroupe\utils\..\config.ini
# Found custom config on: C:\Users\pdasilva\repos\TinyTroupe\examples\config.ini
# TinyTroupe version: 0.5.1
# Current date and time (local): 2025-07-26 14:49:21
# Current date and time (UTC):   2025-07-26 17:49:21
#
# =================================
# Current TinyTroupe configuration
# =================================
# [OpenAI]
# api_type = openai
# azure_api_version = 2024-08-01-preview
# model = gpt-4.1-mini
# reasoning_model = o3-mini
# embedding_model = text-embedding-3-small
# max_tokens = 32000
# temperature = 1.5
# freq_penalty = 0.1
# presence_penalty = 0.1
# timeout = 480
# max_attempts = 5
# waiting_time = 0
# exponential_backoff_factor = 5
# reasoning_effort = high
# cache_api_calls = False
# cache_file_name = openai_api_cache.pickle
# max_content_display_length = 1024
# azure_embedding_model_api_version = 2023-05-15
#
# [Simulation]
# parallel_agent_generation = True
# parallel_agent_actions = True
# rai_harmful_content_prevention = True
# rai_copyright_infringement_prevention = True
#
# [Cognition]
# enable_memory_consolidation = True
# min_episode_length = 15
# max_episode_length = 50
# episodic_memory_fixed_prefix_length = 10
# episodic_memory_lookback_length = 20
#
# [ActionGenerator]
# max_attempts = 2
# enable_quality_checks = False
# enable_regeneration = True
# enable_direct_correction = False
# enable_quality_check_for_persona_adherence = True
# enable_quality_check_for_selfconsistency = False
# enable_quality_check_for_fluency = False
# enable_quality_check_for_suitability = False
# enable_quality_check_for_similarity = False
# continue_on_failure = True
# quality_threshold = 5
#
# [Logging]
# loglevel = ERROR

# %%
lisa = TinyPerson.load_specification("./agents/Lisa.agent.json")  # Lisa, the data scientist
oscar = TinyPerson.load_specification("./agents/Oscar.agent.json")  # Oscar, the architect

# %%
world = TinyWorld("Chat Room", [lisa, oscar])
world.make_everyone_accessible()

# %%
lisa.listen("Talk to Oscar to know more about him")
world.run(4)
# Out:
# USER --> Lisa Carter: [CONVERSATION]
#           > Talk to Oscar to know more about him
# ────────────────────────────────────────────── Chat Room step 1 of 4 ──────────────────────────────────────────────
# Oscar acts: [TALK]
#            > Good morning! How can I assist you today with your architectural needs or any questions
#            > you might have?
# Lisa Carter acts: [TALK]
#                  > Hi Oscar, I'd like to know more about you. Could you tell me a bit about
#                  > yourself?
# Oscar acts: [DONE]
# Lisa Carter acts: [DONE]
# Lisa Carter --> Oscar: [CONVERSATION]
#                  > Hi Oscar, I'd like to know more about you. Could you tell me a bit about
#                  > yourself?
# Oscar --> Lisa Carter: [CONVERSATION]
#            > Good morning! How can I assist you today with your architectural needs or any questions
#            > you might have?
# ────────────────────────────────────────────── Chat Room step 2 of 4 ──────────────────────────────────────────────
# Lisa Carter acts: [THINK]
#                  > Oscar greeted me warmly and offered assistance with architectural needs or
#                  > questions. I need to clarify the context of our conversation since I initially
#                  > wanted to know more about him personally, not about architecture. I should
#                  > respond politely and steer the conversation towards learning about him as a
#                  > person.
# Oscar acts: [THINK]
#            > Lisa wants to know more about me. I should introduce myself warmly and professionally,
#            > highlighting my background in architecture, my passion for sustainable design, and a
#            > bit about my personal interests to make the conversation engaging and approachable.
# Lisa Carter acts: [TALK]
#                  > Good morning, Oscar! Thanks for the offer. Actually, I was hoping to learn a bit
#                  > more about you personally. Could you tell me about your background or interests?
# Lisa Carter acts: [DONE]
# Oscar acts: [TALK]
#            > Hi Lisa! I'm Oscar, an architect working at Awesome Inc. I specialize in creating
#            > standard elements for new apartment buildings, focusing on designs that are functional,
#            > aesthetically pleasing, and sustainable. I have a Master's from the Technical
#            > University of Munich, where I worked on sustainable modular housing solutions. Outside
#            > of work, I enjoy playing the guitar, reading science fiction, and exploring modernist
#            > architecture. I also have a Golden Retriever named Bruno who keeps me active with daily
#            > jogs and walks. What about you?
# Oscar acts: [DONE]
# Lisa Carter --> Oscar: [CONVERSATION]
#                  > Good morning, Oscar! Thanks for the offer. Actually, I was hoping to learn a bit
#                  > more about you personally. Could you tell me about your background or interests?
# Oscar --> Lisa Carter: [CONVERSATION]
#            > Hi Lisa! I'm Oscar, an architect working at Awesome Inc. I specialize in creating
#            > standard elements for new apartment buildings, focusing on designs that are functional,
#            > aesthetically pleasing, and sustainable. I have a Master's from the Technical
#            > University of Munich, where I worked on sustainable modular housing solutions. Outside
#            > of work, I enjoy playing the guitar, reading science fiction, and exploring modernist
#            > architecture. I also have a Golden Retriever named Bruno who keeps me active with daily
#            > jogs and walks. What about you?
# ────────────────────────────────────────────── Chat Room step 3 of 4 ──────────────────────────────────────────────
# Oscar acts: [THINK]
#            > Lisa is asking again about my background and interests, emphasizing a personal angle. I
#            > should focus more on my personal story, such as growing up in Bavaria, my parents being
#            > educators, my passion for nature and sustainability, and how these influenced my career
#            > and hobbies like playing guitar and reading science fiction. This will make the
#            > conversation more personal and engaging.
# Lisa Carter acts: [THINK]
#                  > Oscar shared a detailed introduction about himself: his profession as an
#                  > architect at Awesome Inc., his specialization in functional, aesthetic, and
#                  > sustainable apartment building elements, his education background with a Master's
#                  > from Technical University of Munich focusing on sustainable modular housing, and
#                  > his personal interests including playing guitar, reading science fiction,
#                  > exploring modernist architecture, and having a Golden Retriever named Bruno. He
#                  > also asked about me. I should respond by briefly sharing my background and
#                  > interests to build rapport and continue the conversation.
# Oscar acts: [TALK]
#            > Sure, Lisa! I grew up in a small town in Bavaria surrounded by beautiful forests and
#            > nature, which really sparked my love for sustainable and nature-inspired design. My
#            > parents were educators who always encouraged creativity and curiosity, so I was lucky
#            > to have that supportive environment. During my postgraduate years, I worked at a firm
#            > in Copenhagen that specialized in green architecture, which deepened my passion for
#            > eco-friendly urban design. Outside of work, I enjoy playing the guitar to unwind and
#            > reading science fiction books. These interests help me stay creative and inspired in my
#            > architectural projects. What about you?
# Lisa Carter acts: [TALK]
#                  > Hi Oscar! Thanks for sharing about yourself. I’m Lisa, a data scientist at
#                  > Microsoft on the M365 Search team. I focus on improving search relevance using
#                  > machine learning models. Outside of work, I enjoy cooking, playing the piano, and
#                  > watching comedies and thrillers. It’s great to meet someone who also appreciates
#                  > design and creativity! How did you get interested in architecture?
# Oscar acts: [DONE]
# Lisa Carter acts: [DONE]
# Lisa Carter --> Oscar: [CONVERSATION]
#                  > Hi Oscar! Thanks for sharing about yourself. I’m Lisa, a data scientist at
#                  > Microsoft on the M365 Search team. I focus on improving search relevance using
#                  > machine learning models. Outside of work, I enjoy cooking, playing the piano, and
#                  > watching comedies and thrillers. It’s great to meet someone who also appreciates
#                  > design and creativity! How did you get interested in architecture?
# Oscar --> Lisa Carter: [CONVERSATION]
#            > Sure, Lisa! I grew up in a small town in Bavaria surrounded by beautiful forests and
#            > nature, which really sparked my love for sustainable and nature-inspired design. My
#            > parents were educators who always encouraged creativity and curiosity, so I was lucky
#            > to have that supportive environment. During my postgraduate years, I worked at a firm
#            > in Copenhagen that specialized in green architecture, which deepened my passion for
#            > eco-friendly urban design. Outside of work, I enjoy playing the guitar to unwind and
#            > reading science fiction books. These interests help me stay creative and inspired in my
#            > architectural projects. What about you?
# ────────────────────────────────────────────── Chat Room step 4 of 4 ──────────────────────────────────────────────
# Oscar acts: [THINK]
#            > Lisa has introduced herself and shared her interests, which are quite diverse and
#            > creative. She asked how I got interested in architecture. I should respond by
#            > explaining my early exposure to nature and creativity, influenced by my upbringing in
#            > Bavaria and my parents' encouragement, as well as my passion for sustainable design.
#            > This will connect well with her appreciation for design and creativity.
# Lisa Carter acts: [THINK]
#                  > Oscar shared more about his background growing up in Bavaria surrounded by
#                  > nature, which inspired his passion for sustainable design. His parents were
#                  > educators who encouraged creativity and curiosity. He also worked in Copenhagen
#                  > on green architecture, which deepened his eco-friendly urban design interest. He
#                  > enjoys playing guitar and reading science fiction to stay creative. He asked
#                  > about me again. I should respond by sharing my own background and interests,
#                  > emphasizing my passion for AI and creativity, to keep the conversation engaging
#                  > and balanced.
# Oscar acts: [TALK]
#            > Hi Lisa! It's great to meet you. My interest in architecture really grew from my
#            > childhood in Bavaria, surrounded by nature and inspired by my parents who encouraged
#            > creativity. I was always fascinated by how spaces can influence well-being and
#            > community. Later, during my studies and work, I became passionate about sustainable
#            > design because I believe architecture should respect the environment while being
#            > functional and beautiful. It sounds like we both appreciate creativity in our own ways!
# Lisa Carter acts: [TALK]
#                  > Thanks for sharing, Oscar! I grew up in Vancouver, Canada, in a tech-savvy family
#                  > that encouraged my curiosity from a young age. I pursued data science because I’m
#                  > passionate about AI and how it can improve human productivity. Outside of work, I
#                  > love experimenting with new recipes, playing the piano, and watching comedies and
#                  > thrillers to unwind. It sounds like we both find creativity important in our
#                  > lives!
# Oscar acts: [DONE]
# Lisa Carter acts: [DONE]
# Lisa Carter --> Oscar: [CONVERSATION]
#                  > Thanks for sharing, Oscar! I grew up in Vancouver, Canada, in a tech-savvy family
#                  > that encouraged my curiosity from a young age. I pursued data science because I’m
#                  > passionate about AI and how it can improve human productivity. Outside of work, I
#                  > love experimenting with new recipes, playing the piano, and watching comedies and
#                  > thrillers to unwind. It sounds like we both find creativity important in our
#                  > lives!
# Oscar --> Lisa Carter: [CONVERSATION]
#            > Hi Lisa! It's great to meet you. My interest in architecture really grew from my
#            > childhood in Bavaria, surrounded by nature and inspired by my parents who encouraged
#            > creativity. I was always fascinated by how spaces can influence well-being and
#            > community. Later, during my studies and work, I became passionate about sustainable
#            > design because I believe architecture should respect the environment while being
#            > functional and beautiful. It sounds like we both appreciate creativity in our own ways!

# %%
lisa.pp_current_interactions()
# Out:
# **** BEGIN SIMULATION TRAJECTORY FOR Lisa Carter ****
# Agent simulation trajectory event #0:
# >>>>>>>>> Date and time of events: 2025-07-26T14:49:32.507756
# USER --> Lisa Carter: [CONVERSATION]
#           > Talk to Oscar to know more about him
# Agent simulation trajectory event #1:
# >>>>>>>>> Date and time of events: 2025-07-26T14:49:32.507756
# Lisa Carter acts: [TALK]
#                  > Hi Oscar, I'd like to know more about you. Could you tell me a bit about
#                  > yourself?
# Agent simulation trajectory event #2:
# >>>>>>>>> Date and time of events: 2025-07-26T14:49:32.507756
# Lisa Carter acts: [DONE]
#
# Agent simulation trajectory event #3:
# >>>>>>>>> Date and time of events: 2025-07-26T14:49:32.507756
# Oscar --> Lisa Carter: [CONVERSATION]
#            > Good morning! How can I assist you today with your architectural needs or any questions
#            > you might have?
# Agent simulation trajectory event #4:
# >>>>>>>>> Date and time of events: 2025-07-26T14:49:32.507756
# Lisa Carter acts: [THINK]
#                  > Oscar greeted me warmly and offered assistance with architectural needs or
#                  > questions. I need to clarify the context of our conversation since I initially
#                  > wanted to know more about him personally, not about architecture. I should
#                  > respond politely and steer the conversation towards learning about him as a
#                  > person.
# Agent simulation trajectory event #5:
# >>>>>>>>> Date and time of events: 2025-07-26T14:49:32.507756
# Lisa Carter acts: [TALK]
#                  > Good morning, Oscar! Thanks for the offer. Actually, I was hoping to learn a bit
#                  > more about you personally. Could you tell me about your background or interests?
# Agent simulation trajectory event #6:
# >>>>>>>>> Date and time of events: 2025-07-26T14:49:32.507756
# Lisa Carter acts: [DONE]
#
# Agent simulation trajectory event #7:
# >>>>>>>>> Date and time of events: 2025-07-26T14:49:32.507756
# Oscar --> Lisa Carter: [CONVERSATION]
#            > Hi Lisa! I'm Oscar, an architect working at Awesome Inc. I specialize in creating
#            > standard elements for new apartment buildings, focusing on designs that are functional,
#            > aesthetically pleasing, and sustainable. I have a Master's from the Technical
#            > University of Munich, where I worked on sustainable modular housing solutions. Outside
#            > of work, I enjoy playing the guitar, reading science fiction, and exploring modernist
#            > architecture. I also have a Golden Retriever named Bruno who keeps me active with daily
#            > jogs and walks. What about you?
# Agent simulation trajectory event #8:
# >>>>>>>>> Date and time of events: 2025-07-26T14:49:32.507756
# Lisa Carter acts: [THINK]
#                  > Oscar shared a detailed introduction about himself: his profession as an
#                  > architect at Awesome Inc., his specialization in functional, aesthetic, and
#                  > sustainable apartment building elements, his education background with a Master's
#                  > from Technical University of Munich focusing on sustainable modular housing, and
#                  > his personal interests including playing guitar, reading science fiction,
#                  > exploring modernist architecture, and having a Golden Retriever named Bruno. He
#                  > also asked about me. I should respond by briefly sharing my background and
#                  > interests to build rapport and continue the conversation.
# Agent simulation trajectory event #9:
# >>>>>>>>> Date and time of events: 2025-07-26T14:49:32.507756
# Lisa Carter acts: [TALK]
#                  > Hi Oscar! Thanks for sharing about yourself. I’m Lisa, a data scientist at
#                  > Microsoft on the M365 Search team. I focus on improving search relevance using
#                  > machine learning models. Outside of work, I enjoy cooking, playing the piano, and
#                  > watching comedies and thrillers. It’s great to meet someone who also appreciates
#                  > design and creativity! How did you get interested in architecture?
# Agent simulation trajectory event #10:
# >>>>>>>>> Date and time of events: 2025-07-26T14:49:32.507756
# Lisa Carter acts: [DONE]
#
# Agent simulation trajectory event #11:
# >>>>>>>>> Date and time of events: 2025-07-26T14:49:32.507756
# Oscar --> Lisa Carter: [CONVERSATION]
#            > Sure, Lisa! I grew up in a small town in Bavaria surrounded by beautiful forests and
#            > nature, which really sparked my love for sustainable and nature-inspired design. My
#            > parents were educators who always encouraged creativity and curiosity, so I was lucky
#            > to have that supportive environment. During my postgraduate years, I worked at a firm
#            > in Copenhagen that specialized in green architecture, which deepened my passion for
#            > eco-friendly urban design. Outside of work, I enjoy playing the guitar to unwind and
#            > reading science fiction books. These interests help me stay creative and inspired in my
#            > architectural projects. What about you?
# Agent simulation trajectory event #12:
# >>>>>>>>> Date and time of events: 2025-07-26T14:49:32.507756
# Lisa Carter acts: [THINK]
#                  > Oscar shared more about his background growing up in Bavaria surrounded by
#                  > nature, which inspired his passion for sustainable design. His parents were
#                  > educators who encouraged creativity and curiosity. He also worked in Copenhagen
#                  > on green architecture, which deepened his eco-friendly urban design interest. He
#                  > enjoys playing guitar and reading science fiction to stay creative. He asked
#                  > about me again. I should respond by sharing my own background and interests,
#                  > emphasizing my passion for AI and creativity, to keep the conversation engaging
#                  > and balanced.
# Agent simulation trajectory event #13:
# >>>>>>>>> Date and time of events: 2025-07-26T14:49:32.507756
# Lisa Carter acts: [TALK]
#                  > Thanks for sharing, Oscar! I grew up in Vancouver, Canada, in a tech-savvy family
#                  > that encouraged my curiosity from a young age. I pursued data science because I’m
#                  > passionate about AI and how it can improve human productivity. Outside of work, I
#                  > love experimenting with new recipes, playing the piano, and watching comedies and
#                  > thrillers to unwind. It sounds like we both find creativity important in our
#                  > lives!
# Agent simulation trajectory event #14:
# >>>>>>>>> Date and time of events: 2025-07-26T14:49:32.507756
# Lisa Carter acts: [DONE]
#
# Agent simulation trajectory event #15:
# >>>>>>>>> Date and time of events: 2025-07-26T14:49:32.507756
# Oscar --> Lisa Carter: [CONVERSATION]
#            > Hi Lisa! It's great to meet you. My interest in architecture really grew from my
#            > childhood in Bavaria, surrounded by nature and inspired by my parents who encouraged
#            > creativity. I was always fascinated by how spaces can influence well-being and
#            > community. Later, during my studies and work, I became passionate about sustainable
#            > design because I believe architecture should respect the environment while being
#            > functional and beautiful. It sounds like we both appreciate creativity in our own ways!
# The last agent simulation trajectory event number was 15, thus the current number of the NEXT POTENTIAL TRAJECTORY
# EVENT is 16.
# **** END SIMULATION TRAJECTORY FOR Lisa Carter ****

# %%
oscar.pp_current_interactions()
# Out:
# **** BEGIN SIMULATION TRAJECTORY FOR Oscar ****
# Agent simulation trajectory event #0:
# >>>>>>>>> Date and time of events: 2025-07-26T14:49:32.507756
# Oscar acts: [TALK]
#            > Good morning! How can I assist you today with your architectural needs or any questions
#            > you might have?
# Agent simulation trajectory event #1:
# >>>>>>>>> Date and time of events: 2025-07-26T14:49:32.507756
# Oscar acts: [DONE]
#
# Agent simulation trajectory event #2:
# >>>>>>>>> Date and time of events: 2025-07-26T14:49:32.507756
# Lisa Carter --> Oscar: [CONVERSATION]
#                  > Hi Oscar, I'd like to know more about you. Could you tell me a bit about
#                  > yourself?
# Agent simulation trajectory event #3:
# >>>>>>>>> Date and time of events: 2025-07-26T14:49:32.507756
# Oscar acts: [THINK]
#            > Lisa wants to know more about me. I should introduce myself warmly and professionally,
#            > highlighting my background in architecture, my passion for sustainable design, and a
#            > bit about my personal interests to make the conversation engaging and approachable.
# Agent simulation trajectory event #4:
# >>>>>>>>> Date and time of events: 2025-07-26T14:49:32.507756
# Oscar acts: [TALK]
#            > Hi Lisa! I'm Oscar, an architect working at Awesome Inc. I specialize in creating
#            > standard elements for new apartment buildings, focusing on designs that are functional,
#            > aesthetically pleasing, and sustainable. I have a Master's from the Technical
#            > University of Munich, where I worked on sustainable modular housing solutions. Outside
#            > of work, I enjoy playing the guitar, reading science fiction, and exploring modernist
#            > architecture. I also have a Golden Retriever named Bruno who keeps me active with daily
#            > jogs and walks. What about you?
# Agent simulation trajectory event #5:
# >>>>>>>>> Date and time of events: 2025-07-26T14:49:32.507756
# Oscar acts: [DONE]
#
# Agent simulation trajectory event #6:
# >>>>>>>>> Date and time of events: 2025-07-26T14:49:32.507756
# Lisa Carter --> Oscar: [CONVERSATION]
#                  > Good morning, Oscar! Thanks for the offer. Actually, I was hoping to learn a bit
#                  > more about you personally. Could you tell me about your background or interests?
# Agent simulation trajectory event #7:
# >>>>>>>>> Date and time of events: 2025-07-26T14:49:32.507756
# Oscar acts: [THINK]
#            > Lisa is asking again about my background and interests, emphasizing a personal angle. I
#            > should focus more on my personal story, such as growing up in Bavaria, my parents being
#            > educators, my passion for nature and sustainability, and how these influenced my career
#            > and hobbies like playing guitar and reading science fiction. This will make the
#            > conversation more personal and engaging.
# Agent simulation trajectory event #8:
# >>>>>>>>> Date and time of events: 2025-07-26T14:49:32.507756
# Oscar acts: [TALK]
#            > Sure, Lisa! I grew up in a small town in Bavaria surrounded by beautiful forests and
#            > nature, which really sparked my love for sustainable and nature-inspired design. My
#            > parents were educators who always encouraged creativity and curiosity, so I was lucky
#            > to have that supportive environment. During my postgraduate years, I worked at a firm
#            > in Copenhagen that specialized in green architecture, which deepened my passion for
#            > eco-friendly urban design. Outside of work, I enjoy playing the guitar to unwind and
#            > reading science fiction books. These interests help me stay creative and inspired in my
#            > architectural projects. What about you?
# Agent simulation trajectory event #9:
# >>>>>>>>> Date and time of events: 2025-07-26T14:49:32.507756
# Oscar acts: [DONE]
#
# Agent simulation trajectory event #10:
# >>>>>>>>> Date and time of events: 2025-07-26T14:49:32.507756
# Lisa Carter --> Oscar: [CONVERSATION]
#                  > Hi Oscar! Thanks for sharing about yourself. I’m Lisa, a data scientist at
#                  > Microsoft on the M365 Search team. I focus on improving search relevance using
#                  > machine learning models. Outside of work, I enjoy cooking, playing the piano, and
#                  > watching comedies and thrillers. It’s great to meet someone who also appreciates
#                  > design and creativity! How did you get interested in architecture?
# Agent simulation trajectory event #11:
# >>>>>>>>> Date and time of events: 2025-07-26T14:49:32.507756
# Oscar acts: [THINK]
#            > Lisa has introduced herself and shared her interests, which are quite diverse and
#            > creative. She asked how I got interested in architecture. I should respond by
#            > explaining my early exposure to nature and creativity, influenced by my upbringing in
#            > Bavaria and my parents' encouragement, as well as my passion for sustainable design.
#            > This will connect well with her appreciation for design and creativity.
# Agent simulation trajectory event #12:
# >>>>>>>>> Date and time of events: 2025-07-26T14:49:32.507756
# Oscar acts: [TALK]
#            > Hi Lisa! It's great to meet you. My interest in architecture really grew from my
#            > childhood in Bavaria, surrounded by nature and inspired by my parents who encouraged
#            > creativity. I was always fascinated by how spaces can influence well-being and
#            > community. Later, during my studies and work, I became passionate about sustainable
#            > design because I believe architecture should respect the environment while being
#            > functional and beautiful. It sounds like we both appreciate creativity in our own ways!
# Agent simulation trajectory event #13:
# >>>>>>>>> Date and time of events: 2025-07-26T14:49:32.507756
# Oscar acts: [DONE]
#
# Agent simulation trajectory event #14:
# >>>>>>>>> Date and time of events: 2025-07-26T14:49:32.507756
# Lisa Carter --> Oscar: [CONVERSATION]
#                  > Thanks for sharing, Oscar! I grew up in Vancouver, Canada, in a tech-savvy family
#                  > that encouraged my curiosity from a young age. I pursued data science because I’m
#                  > passionate about AI and how it can improve human productivity. Outside of work, I
#                  > love experimenting with new recipes, playing the piano, and watching comedies and
#                  > thrillers to unwind. It sounds like we both find creativity important in our
#                  > lives!
# The last agent simulation trajectory event number was 14, thus the current number of the NEXT POTENTIAL TRAJECTORY
# EVENT is 15.
# **** END SIMULATION TRAJECTORY FOR Oscar ****
